# %%
import openreview
import pandas as pd
from selenium import webdriver
import re
import difflib
from datetime import datetime
from pyarxiv import query, download_entries
from pyarxiv.arxiv_categories import ArxivCategory, arxiv_category_map

_RE_COMBINE_WHITESPACE = re.compile(r"\s+")

c = openreview.Client(baseurl='https://openreview.net')

# %% [markdown]
# # openreview data

# %%
submissions = openreview.tools.iterget_notes(c, invitation='ICLR.cc/2018/Conference/-/Blind_Submission')
submissions_by_forum = {n.forum: n for n in submissions}

# %%
submissions_by_forum["Hk6kPgZA-"].content
# Out:
# {'title': 'Certifying Some Distributional Robustness with Principled Adversarial Training',
#  'abstract': 'Neural networks are vulnerable to adversarial examples and researchers have proposed many heuristic attack and defense mechanisms. We address this problem through the principled lens of distributionally robust optimization, which guarantees performance under adversarial input perturbations.  By considering a Lagrangian penalty formulation of perturbing the underlying data distribution in a Wasserstein ball, we provide a training procedure that augments model parameter updates with worst-case perturbations of training data. For smooth losses, our procedure provably achieves moderate levels of robustness with little computational or statistical cost relative to empirical risk minimization. Furthermore, our statistical guarantees allow us to efficiently certify robustness for the population loss. For imperceptible perturbations, our method matches or outperforms heuristic approaches.\n',
#  'pdf': '/pdf/f35b7c6c945a42b2b053053616d2393ae0ee6304.pdf',
#  'TL;DR': 'We provide a fast, principled adversarial training procedure with computational and statistical performance guarantees.',
#  'paperhash': 'sinha|certifying_some_distributional_robustness_with_principled_adversarial_training',
#  'authors': ['Aman Sinha', 'Hongseok Namkoong', 'John Duchi'],
#  'keywords': ['adversarial training',
#   'distributionally robust optimization',
#   'deep learning',
#   'optimization',
#   'learning theory'],
#  'authorids': ['amans@stanford.edu',
#   'hnamk@stanford.edu',
#   'jduchi@stanford.edu'],
#  '_bibtex': '@inproceedings{\nsinha2018certifiable,\ntitle={Certifiable Distributional Robustness with Principled Adversarial Training},\nauthor={Aman Sinha and Hongseok Namkoong and John Duchi},\nbooktitle={International Conference on Learning Representations},\nyear={2018},\nurl={https://openreview.net/forum?id=Hk6kPgZA-},\n}'}

# %%
forum_title = [submissions_by_forum[forum].content['title'] for forum in submissions_by_forum ]
author_1 = [submissions_by_forum[forum].content['authors'][0] for forum in submissions_by_forum ]
author_2 = [submissions_by_forum[forum].content['authors'][1] if len(submissions_by_forum[forum].content['authors']) >=2 else "" for forum in submissions_by_forum ]
author_3 = [submissions_by_forum[forum].content['authors'][2] if len(submissions_by_forum[forum].content['authors']) >=3 else "" for forum in submissions_by_forum ]
email_1 = [submissions_by_forum[forum].content['authorids'][0] for forum in submissions_by_forum ]
email_2 = [submissions_by_forum[forum].content['authorids'][1] if len(submissions_by_forum[forum].content['authorids']) >=2 else "" for forum in submissions_by_forum ]
email_3 = [submissions_by_forum[forum].content['authorids'][2] if len(submissions_by_forum[forum].content['authorids']) >=3 else "" for forum in submissions_by_forum ]

open_review_data = pd.DataFrame({"title":forum_title, "author_1":author_1, "author_2":author_2,"author_3":author_3,
                                "email_1": email_1, "email_2": email_2, "email_3":email_3})
open_review_data["accepted"] = ""

# %%
driver = webdriver.Chrome()
driver.get("https://openreview.net/group?id=ICLR.cc/2018/Conference#accepted-oral-papers")
driver.implicitly_wait(10)
content = driver.find_elements_by_class_name("note")
accepted_papers = [i.text.split('\n')[0].strip() for i in content if i.text.split('\n')[0] != '' ]
driver.quit()

driver = webdriver.Chrome()
driver.get("https://openreview.net/group?id=ICLR.cc/2018/Conference#rejected-papers")
driver.implicitly_wait(10)
driver.find_element_by_link_text("Rejected Papers").click()
driver.implicitly_wait(10)
content = driver.find_elements_by_class_name("note")
rejected_papers = [i.text.split('\n')[0].strip() for i in content if i.text.split('\n')[0] != '' ]
driver.quit()


driver = webdriver.Chrome()
driver.get("https://openreview.net/group?id=ICLR.cc/2018/Conference#accepted-poster-papers")
driver.implicitly_wait(10)
driver.find_element_by_link_text("Poster Papers").click()
driver.implicitly_wait(10)
content = driver.find_elements_by_class_name("note")
accepted_poster_papers = [i.text.split('\n')[0].strip() for i in content if i.text.split('\n')[0] != '' ]
driver.quit()


driver = webdriver.Chrome()
driver.get("https://openreview.net/group?id=ICLR.cc/2018/Conference#workshop-papers")
driver.implicitly_wait(10)
driver.find_element_by_link_text("Invited to submit to Workshop").click()
driver.implicitly_wait(10)
content = driver.find_elements_by_class_name("note")
workshop_papers = [i.text.split('\n')[0].strip() for i in content if i.text.split('\n')[0] != '' ]
driver.quit()


driver = webdriver.Chrome()
driver.get("https://openreview.net/group?id=ICLR.cc/2018/Conference#withdrawn-papers")
driver.implicitly_wait(10)
driver.find_element_by_link_text("Withdrawn Papers").click()
driver.implicitly_wait(10)
content = driver.find_elements_by_class_name("note")
withdrawn_papers = [i.text.split('\n')[0].strip() for i in content if i.text.split('\n')[0] != '' ]
driver.quit()

# %%
for i in range(len(open_review_data)) : 
    if _RE_COMBINE_WHITESPACE.sub(" ", open_review_data.loc[i, "title"]).strip() in accepted_papers:
        open_review_data.loc[i, "accepted"] = "a"
    if _RE_COMBINE_WHITESPACE.sub(" ", open_review_data.loc[i, "title"]).strip() in rejected_papers:
        open_review_data.loc[i, "accepted"] = "r"
    if _RE_COMBINE_WHITESPACE.sub(" ", open_review_data.loc[i, "title"]).strip() in withdrawn_papers:
        open_review_data.loc[i, "accepted"] = "w"
    if _RE_COMBINE_WHITESPACE.sub(" ", open_review_data.loc[i, "title"]).strip() in accepted_poster_papers:
        open_review_data.loc[i, "accepted"] = "ap"
    if _RE_COMBINE_WHITESPACE.sub(" ", open_review_data.loc[i, "title"]).strip() in workshop_papers:
        open_review_data.loc[i, "accepted"] = "wp"

# %%
open_review_data
# Out:
#                                                  title               author_1  \
# 0    Certifying Some Distributional Robustness with...             Aman Sinha
# 1    Parametric Information Bottleneck to Optimize ...        Thanh T. Nguyen
# 2      Towards Neural Phrase-based Machine Translation           Po-Sen Huang
# 3    Weightless: Lossy Weight Encoding For Deep Neu...         Brandon Reagen
# 4    Interactive Grounded Language Acquisition and ...              Haonan Yu
# 5     A Boo(n) for Evaluating Architecture Performance          Ondrej Bajgar
# 6    Countering Adversarial Images using Input Tran...              Chuan Guo
# 7           A Neural Representation of Sketch Drawings               David Ha
# 8    The Kanerva Machine: A Generative Distributed ...                 Yan Wu
# 9    Minimax Curriculum Learning: Machine Teaching ...            Tianyi Zhou
# 10   Multi-View Data Generation Without View Superv...           Mickael Chen
# 11   Towards Binary-Valued Gates for Robust LSTM Tr...             Zhuohan Li
# 12   On the importance of single directions for gen...          Ari S. Morcos
# 13                      Variational Continual Learning        Cuong V. Nguyen
# 14   Go for a Walk and Arrive at the Answer: Reason...           Rajarshi Das
# 15          Learning to Represent Programs with Graphs    Miltiadis Allamanis
# 16   Variational image compression with a scale hyp...         Johannes Ballé
# 17   Simulating Action Dynamics with Neural Process...       Antoine Bosselut
# 18   Evidence Aggregation for Answer Re-Ranking in ...          Shuohang Wang
# 19   QANet: Combining Local Convolution with Global...           Adams Wei Yu
# 20   Measuring the Intrinsic Dimension of Objective...            Chunyuan Li
# 21   Residual Loss Prediction: Reinforcement Learni...          Hal Daumé III
# 22          Reinforcement Learning Algorithm Selection         Romain Laroche
# 23     Feature Incay for Representation Regularization             Yuhui Yuan
# 24                          Zero-Shot Visual Imitation          Deepak Pathak
# 25   Emergent Communication in a Multi-Modal, Multi...       Katrina Evtimova
# 26   Distributed Fine-tuning of Language Models on ...            Vadim Popov
# 27   Preliminary theoretical troubleshooting in Var...              Shiqi Liu
# 28               On the Convergence of Adam and Beyond       Sashank J. Reddi
# 29          Spatially Transformed Adversarial Examples           Chaowei Xiao
# ..                                                 ...                    ...
# 881  Neural Compositional Denotational Semantics fo...           Nitish Gupta
# 882                               Variational Bi-LSTMs       Samira Shabanian
# 883  TOWARDS ROBOT VISION MODULE DEVELOPMENT WITH E...            Ahmed A Aly
# 884  Towards a Testable Notion of Generalization fo...         Robert Cornish
# 885  3C-GAN: AN CONDITION-CONTEXT-COMPOSITE GENERAT...         Yeu-Chern Harn
# 886  Alpha-divergence bridges maximum likelihood an...       Sotetsu Koyamada
# 887  Don't encrypt the data; just approximate the m...              Xinlei Xu
# 888  An inference-based policy gradient method for ...    Matthew J. A. Smith
# 889  Sequential Coordination of Deep Models for Lea...          Eric Crawford
# 890                  What is image captioning made of?     Pranava Madhyastha
# 891                                  Fraternal Dropout           Konrad Zolna
# 892             TD Learning with Constrained Gradients         Ishan Durugkar
# 893  WSNet: Learning Compact and Efficient Networks...            Xiaojie Jin
# 894  Generative Entity Networks: Disentangling Enti...           Charlie Nash
# 895  Prediction Under Uncertainty with Error Encodi...          Mikael Henaff
# 896  Noise-Based Regularizers for Recurrent Neural ...          Adji B. Dieng
# 897  Learning To Generate Reviews and Discovering S...           Alec Radford
# 898  Deep learning mutation prediction enables earl...  Steven T. Kothen-Hill
# 899  Covariant Compositional Networks For Learning ...            Risi Kondor
# 900  A novel method to determine the number of late...      Asana Neishabouri
# 901  Automatic Goal Generation for Reinforcement Le...             David Held
# 902  A Goal-oriented Neural Conversation Model by S...                Wei Wei
# 903  Bayesian Uncertainty Estimation for Batch Norm...           Mattias Teye
# 904  Learning Efficient Tensor Representations with...             Qibin Zhao
# 905  Video Action Segmentation with Hybrid Temporal...                Li Ding
# 906  The Variational Homoencoder: Learning to Infer...            Luke Hewitt
# 907  Hyperedge2vec: Distributed Representations for...           Ankit Sharma
# 908  Combining Model-based and Model-free RL via Mu...               Tong Che
# 909                Tree2Tree Learning with Memory Unit              Ning Miao
# 910  Revisiting Knowledge Base Embedding as Tensor ...           Jiezhong Qiu
#
#                 author_2             author_3                        email_1  \
# 0      Hongseok Namkoong           John Duchi             amans@stanford.edu
# 1            Jaesik Choi                           thanhnguyen2792@gmail.com
# 2             Chong Wang          Sitao Huang         huang.person@gmail.com
# 3             Udit Gupta         Robert Adolf         reagen@fas.harvard.edu
# 4          Haichao Zhang               Wei Xu             haonanyu@baidu.com
# 5          Rudolf Kadlec  and Jan Kleindienst              ondrej@bajgar.org
# 6            Mayank Rana      Moustapha Cisse              cg563@cornell.edu
# 7            Douglas Eck                                  hadavid@google.com
# 8             Greg Wayne          Alex Graves               yanwu@google.com
# 9            Jeff Bilmes                         tianyi.david.zhou@gmail.com
# 10       Ludovic Denoyer     Thierry Artières           mickael.chen@lip6.fr
# 11                 Di He             Fei Tian           lizhuohan@pku.edu.cn
# 12    David G.T. Barrett   Neil C. Rabinowitz           arimorcos@google.com
# 13           Yingzhen Li         Thang D. Bui                vcn22@cam.ac.uk
# 14   Shehzaad Dhuliawala        Manzil Zaheer          rajarshi@cs.umass.edu
# 15     Marc Brockschmidt      Mahmoud Khademi         miallama@microsoft.com
# 16          David Minnen        Saurabh Singh              jballe@google.com
# 17             Omer Levy         Ari Holtzman     antoineb@cs.washington.edu
# 18                 Mo Yu           Jing Jiang   shwang.2014@phdis.smu.edu.sg
# 19           David Dohan     Minh-Thang Luong               weiyu@cs.cmu.edu
# 20       Heerad Farkhoor          Rosanne Liu           chunyuan.li@duke.edu
# 21         John Langford           Amr Sharaf             hal@umiacs.umd.edu
# 22        Raphael Feraud                            romain.laroche@gmail.com
# 23          Kuiyuan Yang         Jianyuan Guo            yuyua@microsoft.com
# 24      Parsa Mahmoudieh         Guanghao Luo            pathak@berkeley.edu
# 25        Andrew Drozdov          Douwe Kiela                 kve216@nyu.edu
# 26       Mikhail Kudinov  Irina Piontkovskaya            v.popov@samsung.com
# 27             Qian Zhao        Xiangyong Cao       liushiqi@stu.xjtu.edu.cn
# 28           Satyen Kale         Sanjiv Kumar             sashank@google.com
# 29           Jun-Yan Zhu                Bo Li               xiaocw@umich.edu
# ..                   ...                  ...                            ...
# 881           Mike Lewis                               nitishg@cis.upenn.edu
# 882        Devansh Arpit       Adam Trischler          s.shabanian@gmail.com
# 883  Joanne Bechta Dugan                                 aaa2cn@virginia.edu
# 884        Hongseok Yang           Frank Wood       rcornish@robots.ox.ac.uk
# 885       Vladimir Jojic                                   ycharn@cs.unc.edu
# 886         Yuta Kikuchi    Atsunori Kanemura     sotetsu.koyamada@gmail.com
# 887                                                              xxu@hmc.edu
# 888       Herke van Hoof        Joelle Pineau  matthew.smith5@mail.mcgill.ca
# 889  Guillaume Rabusseau        Joelle Pineau   eric.crawford@mail.mcgill.ca
# 890          Josiah Wang         Lucia Specia   p.madhyastha@sheffield.ac.uk
# 891        Devansh Arpit        Dendi Suhubdy         konrad.zolna@gmail.com
# 892          Peter Stone                                ishand@cs.utexas.edu
# 893        Yingzhen Yang              Ning Xu          xiaojie.jin@u.nus.edu
# 894    Sebastian Nowozin         Nate Kushman          charlie.nash@ed.ac.uk
# 895           Junbo Zhao           Yann Lecun                 mbh305@nyu.edu
# 896        Jaan Altosaar     Rajesh Ranganath           abd2141@columbia.edu
# 897     Rafal Jozefowicz       Ilya Sutskever                alec@openai.com
# 898          Asaf Zviran   Rafael C. Schulman        sth2022@med.cornell.edu
# 899        Truong Son Hy           Horace Pan           risi@cs.uchicago.edu
# 900     Michel Desmarais                        asana.neishabouri@polymtl.ca
# 901         Xinyang Geng      Carlos Florensa           dheld@andrew.cmu.edu
# 902           Quoc V. Le        Andrew M. Dai               wewei@google.com
# 903     Hossein Azizpour          Kevin Smith                    teye@kth.se
# 904     Masashi Sugiyama         Longhao Yuan            qibin.zhao@riken.jp
# 905         Chenliang Xu                                liding@rochester.edu
# 906          Andrea Gane       Tommi Jaakkola                    lbh@mit.edu
# 907          Shafiq Joty    Himanshu Kharkwal               sharm170@umn.edu
# 908            Yuchen Lu        George Tucker          gerryche@berkeley.edu
# 909       Hengliang Wang               Ran Le            miaoning@pku.edu.cn
# 910               Hao Ma          Yuxiao Dong               xptree@gmail.com
#
#                                 email_2                           email_3  \
# 0                    hnamk@stanford.edu               jduchi@stanford.edu
# 1                    jaesik@unist.ac.kr
# 2                     chongw@google.com             shuang91@illinois.edu
# 3                  ugupta@g.harvard.edu          rdadolf@seas.harvard.edu
# 4                zhanghaichao@baidu.com                  wei.xu@baidu.com
# 5              rudolf_kadlec@cz.ibm.com                 jankle@cz.ibm.com
# 6                     mayankrana@fb.com             moustaphacisse@fb.com
# 7                       deck@google.com
# 8                  gregwayne@google.com                gravesa@google.com
# 9                         bilmes@uw.edu
# 10              ludovic.denoyer@lip6.fr  thierry.artieres@lif.univ-mrs.fr
# 11                     di_he@pku.edu.cn               fetia@microsoft.com
# 12              barrettdavid@google.com                    ncr@google.com
# 13                      yl494@cam.ac.uk                   tdb40@cam.ac.uk
# 14             sdhuliawala@cs.umass.edu                    manzil@cmu.edu
# 15               mabrocks@microsoft.com                   mkhademi@sfu.ca
# 16                   dminnen@google.com           saurabhsingh@google.com
# 17           omerlevy@cs.washington.edu            ahai@cs.washington.edu
# 18                       yum@us.ibm.com              jingjiang@smu.edu.sg
# 19                    ddohan@google.com             thangluong@google.com
# 20                      heerad@uber.com                  rosanne@uber.com
# 21                         jl@hunch.net                    amr@cs.umd.edu
# 22            raphael.feraud@orange.com
# 23            kuiyuanyang@deepmotion.ai             1701214082@pku.edu.cn
# 24                 parsa.m@berkeley.edu           michaelluo@berkeley.edu
# 25                       apd283@nyu.edu                     dkiela@fb.com
# 26                m.kudinov@samsung.com               p.irina@samsung.com
# 27              dymeng@mail.xjtu.edu.cn          timmy.zhaoqian@gmail.com
# 28                satyenkale@google.com                sanjivk@google.com
# 29                junyanzhu89@gmail.com                 lxbosky@gmail.com
# ..                                  ...                               ...
# 881              mikelewis@facebook.com
# 882              devansharpit@gmail.com      adam.trischler@microsoft.com
# 883                    jbd@virginia.edu
# 884           hongseok.yang@cs.ox.ac.uk             fwood@robots.ox.ac.uk
# 885                    vjojic@gmail.com
# 886
# 887
# 888        herke.vanhoof@mail.mcgill.ca              jpineau@cs.mcgill.ca
# 889  guillaume.rabusseau@mail.mcgill.ca              jpineau@cs.mcgill.ca
# 890            j.k.wang@sheffield.ac.uk          l.specia@sheffield.ac.uk
# 891          devansh.arpit@umontreal.ca                 dasuhubd@ncsu.edu
# 892                pstone@cs.utexas.edu
# 893                 superyyzg@gmail.com                  ning.xu@snap.com
# 894     sebastian.nowozin@microsoft.com                  nate@kushman.org
# 895                      j.zhao@nyu.edu                   yann@cs.nyu.edu
# 896              altosaar@princeton.edu          rajeshr@cs.princeton.edu
# 897                    rafal@openai.com                   ilya@openai.com
# 898                azviran@nygenome.org            rschulman@nygenome.org
# 899            hytruongson@uchicago.edu             hopan@cs.uchicago.edu
# 900         michel.desmarais@polymtl.ca
# 901             young.geng@berkeley.edu             florensa@berkeley.edu
# 902                     adai@google.com                    qvl@google.com
# 903                     azizpour@kth.se                     ksmith@kth.se
# 904                sugi@k.u-tokyo.ac.jp             longhao.yuan@riken.jp
# 905          chenliang.xu@rochester.edu
# 906                       agane@mit.edu               tommi@csail.mit.edu
# 907                   srjoty@ntu.edu.sg     himanshukharkwal765@gmail.com
# 908             luyuchen.paul@gmail.com                    gjt@google.com
# 909                   wanghl@pku.edu.cn                 leran@buaa.edu.cn
# 910                 haoma@microsoft.com             yuxdong@microsoft.com
#
#     accepted
# 0          a
# 1          r
# 2         ap
# 3         wp
# 4         ap
# 5          r
# 6         ap
# 7         ap
# 8         ap
# 9         ap
# 10        ap
# 11         r
# 12        ap
# 13        ap
# 14        ap
# 15         a
# 16        ap
# 17        ap
# 18        ap
# 19        ap
# 20        ap
# 21        ap
# 22        ap
# 23        wp
# 24         a
# 25        ap
# 26        ap
# 27         r
# 28         a
# 29        ap
# ..       ...
# 881        r
# 882        r
# 883        r
# 884        r
# 885        r
# 886        r
# 887        r
# 888        r
# 889        r
# 890        r
# 891       ap
# 892        r
# 893       wp
# 894        r
# 895        r
# 896        r
# 897        r
# 898       wp
# 899       wp
# 900        r
# 901        r
# 902        r
# 903        r
# 904       wp
# 905        r
# 906        r
# 907        r
# 908        r
# 909        r
# 910        r
#
# [911 rows x 8 columns]

# %%
open_review_data.loc[open_review_data['accepted'] == '']
# Out:
# Empty DataFrame
# Columns: [title, author_1, author_2, author_3, email_1, email_2, email_3, accepted]
# Index: []

# %%
open_review_data["accepted"].unique()
# Out:
# array(['a', 'r', 'ap', 'wp'], dtype=object)

# %% [markdown]
# # Arxiv Data

# %%
open_review_data["submitted_arxiv"] = 0
for index, row in open_review_data.iterrows():
    print(index)
    entries = query(title = re.sub(r"[,.;@#?!&$-]+\ *", " ", row['title']))
    #only when search the query, results existed and the title in ARXIV has more than 90% similarity with the title in openreview, and publish data is before 2018-10-01.
    if entries and difflib.SequenceMatcher(None, entries[0]["title"], row['title']).ratio() >= 0.9 and datetime.strptime(entries[0]["published"].split("T")[0], '%Y-%m-%d') < datetime.strptime('2018-10-01', '%Y-%m-%d'):
        print("submitted to arxiv")
        open_review_data.loc[index,"submitted_arxiv"] = 1
# Out:
# 0
# submitted to arxiv
# 1
# 2
# submitted to arxiv
# 3
# submitted to arxiv
# 4
# submitted to arxiv
# 5
# submitted to arxiv
# 6
# submitted to arxiv
# 7
# submitted to arxiv
# 8
# submitted to arxiv
# 9
# 10
# submitted to arxiv
# 11
# submitted to arxiv
# 12
# submitted to arxiv
# 13
# submitted to arxiv
# 14
# submitted to arxiv
# 15
# submitted to arxiv
# 16
# submitted to arxiv
# 17
# submitted to arxiv
# 18
# submitted to arxiv
# 19
# submitted to arxiv
# 20
# submitted to arxiv
# 21
# 22
# submitted to arxiv
# 23
# submitted to arxiv
# 24
# submitted to arxiv
# 25
# submitted to arxiv
# 26
# 27
# 28
# 29
# submitted to arxiv
# 30
# 31
# submitted to arxiv
# 32
# submitted to arxiv
# 33
# 34
# submitted to arxiv
# 35
# submitted to arxiv
# 36
# submitted to arxiv
# 37
# submitted to arxiv
# 38
# submitted to arxiv
# 39
# submitted to arxiv
# 40
# 41
# submitted to arxiv
# 42
# 43
# 44
# submitted to arxiv
# 45
# 46
# submitted to arxiv
# 47
# submitted to arxiv
# 48
# 49
# submitted to arxiv
# 50
# submitted to arxiv
# 51
# submitted to arxiv
# 52
# 53
# submitted to arxiv
# 54
# submitted to arxiv
# 55
# submitted to arxiv
# 56
# 57
# submitted to arxiv
# 58
# submitted to arxiv
# 59
# submitted to arxiv
# 60
# submitted to arxiv
# 61
# submitted to arxiv
# 62
# submitted to arxiv
# 63
# 64
# submitted to arxiv
# 65
# submitted to arxiv
# 66
# submitted to arxiv
# 67
# submitted to arxiv
# 68
# submitted to arxiv
# 69
# submitted to arxiv
# 70
# 71
# submitted to arxiv
# 72
# submitted to arxiv
# 73
# submitted to arxiv
# 74
# submitted to arxiv
# 75
# submitted to arxiv
# 76
# submitted to arxiv
# 77
# submitted to arxiv
# 78
# submitted to arxiv
# 79
# submitted to arxiv
# 80
# submitted to arxiv
# 81
# submitted to arxiv
# 82
# submitted to arxiv
# 83
# submitted to arxiv
# 84
# submitted to arxiv
# 85
# submitted to arxiv
# 86
# submitted to arxiv
# 87
# submitted to arxiv
# 88
# submitted to arxiv
# 89
# submitted to arxiv
# 90
# submitted to arxiv
# 91
# submitted to arxiv
# 92
# submitted to arxiv
# 93
# submitted to arxiv
# 94
# submitted to arxiv
# 95
# submitted to arxiv
# 96
# submitted to arxiv
# 97
# submitted to arxiv
# 98
# submitted to arxiv
# 99
# 100
# submitted to arxiv
# 101
# submitted to arxiv
# 102
# submitted to arxiv
# 103
# submitted to arxiv
# 104
# submitted to arxiv
# 105
# 106
# submitted to arxiv
# 107
# submitted to arxiv
# 108
# submitted to arxiv
# 109
# submitted to arxiv
# 110
# submitted to arxiv
# 111
# 112
# submitted to arxiv
# 113
# 114
# 115
# submitted to arxiv
# 116
# submitted to arxiv
# 117
# submitted to arxiv
# 118
# submitted to arxiv
# 119
# submitted to arxiv
# 120
# 121
# submitted to arxiv
# 122
# submitted to arxiv
# 123
# 124
# submitted to arxiv
# 125
# submitted to arxiv
# 126
# submitted to arxiv
# 127
# submitted to arxiv
# 128
# submitted to arxiv
# 129
# submitted to arxiv
# 130
# submitted to arxiv
# 131
# submitted to arxiv
# 132
# submitted to arxiv
# 133
# submitted to arxiv
# 134
# submitted to arxiv
# 135
# submitted to arxiv
# 136
# submitted to arxiv
# 137
# 138
# submitted to arxiv
# 139
# submitted to arxiv
# 140
# submitted to arxiv
# 141
# submitted to arxiv
# 142
# submitted to arxiv
# 143
# 144
# submitted to arxiv
# 145
# submitted to arxiv
# 146
# submitted to arxiv
# 147
# submitted to arxiv
# 148
# submitted to arxiv
# 149
# submitted to arxiv
# 150
# submitted to arxiv
# 151
# submitted to arxiv
# 152
# submitted to arxiv
# 153
# 154
# submitted to arxiv
# 155
# submitted to arxiv
# 156
# submitted to arxiv
# 157
# submitted to arxiv
# 158
# submitted to arxiv
# 159
# submitted to arxiv
# 160
# submitted to arxiv
# 161
# submitted to arxiv
# 162
# submitted to arxiv
# 163
# submitted to arxiv
# 164
# submitted to arxiv
# 165
# submitted to arxiv
# 166
# submitted to arxiv
# 167
# submitted to arxiv
# 168
# submitted to arxiv
# 169
# submitted to arxiv
# 170
# 171
# submitted to arxiv
# 172
# submitted to arxiv
# 173
# submitted to arxiv
# 174
# submitted to arxiv
# 175
# submitted to arxiv
# 176
# submitted to arxiv
# 177
# submitted to arxiv
# 178
# submitted to arxiv
# 179
# submitted to arxiv
# 180
# submitted to arxiv
# 181
# submitted to arxiv
# 182
# submitted to arxiv
# 183
# submitted to arxiv
# 184
# submitted to arxiv
# 185
# 186
# submitted to arxiv
# 187
# submitted to arxiv
# 188
# submitted to arxiv
# 189
# submitted to arxiv
# 190
# submitted to arxiv
# 191
# submitted to arxiv
# 192
# submitted to arxiv
# 193
# submitted to arxiv
# 194
# submitted to arxiv
# 195
# 196
# submitted to arxiv
# 197
# 198
# 199
# submitted to arxiv
# 200
# submitted to arxiv
# 201
# 202
# submitted to arxiv
# 203
# submitted to arxiv
# 204
# submitted to arxiv
# 205
# submitted to arxiv
# 206
# submitted to arxiv
# 207
# 208
# submitted to arxiv
# 209
# 210
# submitted to arxiv
# 211
# submitted to arxiv
# 212
# submitted to arxiv
# 213
# 214
# 215
# submitted to arxiv
# 216
# submitted to arxiv
# 217
# submitted to arxiv
# 218
# submitted to arxiv
# 219
# submitted to arxiv
# 220
# 221
# 222
# submitted to arxiv
# 223
# submitted to arxiv
# 224
# 225
# 226
# submitted to arxiv
# 227
# 228
# 229
# 230
# submitted to arxiv
# 231
# submitted to arxiv
# 232
# submitted to arxiv
# 233
# submitted to arxiv
# 234
# submitted to arxiv
# 235
# submitted to arxiv
# 236
# submitted to arxiv
# 237
# submitted to arxiv
# 238
# submitted to arxiv
# 239
# submitted to arxiv
# 240
# submitted to arxiv
# 241
# submitted to arxiv
# 242
# 243
# submitted to arxiv
# 244
# submitted to arxiv
# 245
# submitted to arxiv
# 246
# submitted to arxiv
# 247
# submitted to arxiv
# 248
# submitted to arxiv
# 249
# submitted to arxiv
# 250
# submitted to arxiv
# 251
# submitted to arxiv
# 252
# 253
# submitted to arxiv
# 254
# submitted to arxiv
# 255
# submitted to arxiv
# 256
# submitted to arxiv
# 257
# submitted to arxiv
# 258
# 259
# submitted to arxiv
# 260
# submitted to arxiv
# 261
# 262
# 263
# submitted to arxiv
# 264
# 265
# submitted to arxiv
# 266
# 267
# 268
# submitted to arxiv
# 269
# submitted to arxiv
# 270
# submitted to arxiv
# 271
# submitted to arxiv
# 272
# submitted to arxiv
# 273
# submitted to arxiv
# 274
# submitted to arxiv
# 275
# submitted to arxiv
# 276
# submitted to arxiv
# 277
# 278
# 279
# submitted to arxiv
# 280
# submitted to arxiv
# 281
# submitted to arxiv
# 282
# submitted to arxiv
# 283
# submitted to arxiv
# 284
# submitted to arxiv
# 285
# 286
# submitted to arxiv
# 287
# submitted to arxiv
# 288
# 289
# submitted to arxiv
# 290
# submitted to arxiv
# 291
# submitted to arxiv
# 292
# submitted to arxiv
# 293
# submitted to arxiv
# 294
# submitted to arxiv
# 295
# submitted to arxiv
# 296
# 297
# 298
# 299
# submitted to arxiv
# 300
# 301
# 302
# submitted to arxiv
# 303
# submitted to arxiv
# 304
# 305
# 306
# 307
# submitted to arxiv
# 308
# 309
# 310
# submitted to arxiv
# 311
# submitted to arxiv
# 312
# submitted to arxiv
# 313
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322
# submitted to arxiv
# 323
# 324
# 325
# submitted to arxiv
# 326
# submitted to arxiv
# 327
# submitted to arxiv
# 328
# 329
# 330
# submitted to arxiv
# 331
# 332
# 333
# submitted to arxiv
# 334
# 335
# submitted to arxiv
# 336
# 337
# 338
# submitted to arxiv
# 339
# submitted to arxiv
# 340
# submitted to arxiv
# 341
# 342
# submitted to arxiv
# 343
# submitted to arxiv
# 344
# 345
# submitted to arxiv
# 346
# 347
# submitted to arxiv
# 348
# 349
# submitted to arxiv
# 350
# 351
# submitted to arxiv
# 352
# 353
# 354
# submitted to arxiv
# 355
# submitted to arxiv
# 356
# 357
# 358
# 359
# 360
# 361
# 362
# submitted to arxiv
# 363
# 364
# submitted to arxiv
# 365
# 366
# submitted to arxiv
# 367
# submitted to arxiv
# 368
# submitted to arxiv
# 369
# 370
# 371
# 372
# submitted to arxiv
# 373
# submitted to arxiv
# 374
# submitted to arxiv
# 375
# submitted to arxiv
# 376
# 377
# 378
# submitted to arxiv
# 379
# 380
# 381
# 382
# 383
# submitted to arxiv
# 384
# 385
# submitted to arxiv
# 386
# submitted to arxiv
# 387
# 388
# submitted to arxiv
# 389
# 390
# 391
# 392
# submitted to arxiv
# 393
# 394
# 395
# submitted to arxiv
# 396
# 397
# 398
# submitted to arxiv
# 399
# 400
# submitted to arxiv
# 401
# submitted to arxiv
# 402
# 403
# 404
# submitted to arxiv
# 405
# 406
# submitted to arxiv
# 407
# 408
# submitted to arxiv
# 409
# 410
# 411
# 412
# 413
# submitted to arxiv
# 414
# 415
# submitted to arxiv
# 416
# submitted to arxiv
# 417
# 418
# 419
# 420
# 421
# submitted to arxiv
# 422
# submitted to arxiv
# 423
# submitted to arxiv
# 424
# submitted to arxiv
# 425
# 426
# submitted to arxiv
# 427
# 428
# 429
# 430
# 431
# submitted to arxiv
# 432
# 433
# submitted to arxiv
# 434
# 435
# submitted to arxiv
# 436
# 437
# 438
# 439
# submitted to arxiv
# 440
# 441
# submitted to arxiv
# 442
# 443
# 444
# submitted to arxiv
# 445
# 446
# 447
# submitted to arxiv
# 448
# submitted to arxiv
# 449
# 450
# 451
# 452
# 453
# 454
# 455
# submitted to arxiv
# 456
# 457
# submitted to arxiv
# 458
# 459
# submitted to arxiv
# 460
# 461
# submitted to arxiv
# 462
# submitted to arxiv
# 463
# submitted to arxiv
# 464
# submitted to arxiv
# 465
# 466
# 467
# 468
# 469
# 470
# 471
# submitted to arxiv
# 472
# 473
# 474
# 475
# submitted to arxiv
# 476
# submitted to arxiv
# 477
# submitted to arxiv
# 478
# 479
# 480
# 481
# submitted to arxiv
# 482
# 483
# 484
# 485
# 486
# 487
# 488
# submitted to arxiv
# 489
# 490
# 491
# submitted to arxiv
# 492
# submitted to arxiv
# 493
# 494
# 495
# submitted to arxiv
# 496
# 497
# 498
# 499
# 500
# 501
# submitted to arxiv
# 502
# submitted to arxiv
# 503
# submitted to arxiv
# 504
# 505
# 506
# submitted to arxiv
# 507
# 508
# 509
# 510
# 511
# 512
# 513
# 514
# 515
# 516
# submitted to arxiv
# 517
# 518
# 519
# 520
# submitted to arxiv
# 521
# 522
# submitted to arxiv
# 523
# submitted to arxiv
# 524
# 525
# submitted to arxiv
# 526
# 527
# submitted to arxiv
# 528
# submitted to arxiv
# 529
# 530
# 531
# 532
# submitted to arxiv
# 533
# 534
# submitted to arxiv
# 535
# 536
# 537
# 538
# submitted to arxiv
# 539
# 540
# 541
# 542
# 543
# 544
# submitted to arxiv
# 545
# submitted to arxiv
# 546
# 547
# 548
# 549
# submitted to arxiv
# 550
# 551
# 552
# 553
# submitted to arxiv
# 554
# 555
# 556
# 557
# 558
# submitted to arxiv
# 559
# submitted to arxiv
# 560
# submitted to arxiv
# 561
# submitted to arxiv
# 562
# 563
# 564
# 565
# 566
# 567
# 568
# 569
# submitted to arxiv
# 570
# 571
# 572
# 573
# submitted to arxiv
# 574
# submitted to arxiv
# 575
# 576
# 577
# 578
# submitted to arxiv
# 579
# submitted to arxiv
# 580
# submitted to arxiv
# 581
# 582
# 583
# submitted to arxiv
# 584
# 585
# 586
# 587
# submitted to arxiv
# 588
# 589
# 590
# 591
# submitted to arxiv
# 592
# 593
# submitted to arxiv
# 594
# 595
# 596
# 597
# 598
# submitted to arxiv
# 599
# submitted to arxiv
# 600
# 601
# submitted to arxiv
# 602
# submitted to arxiv
# 603
# 604
# 605
# submitted to arxiv
# 606
# 607
# submitted to arxiv
# 608
# submitted to arxiv
# 609
# 610
# submitted to arxiv
# 611
# submitted to arxiv
# 612
# 613
# submitted to arxiv
# 614
# 615
# submitted to arxiv
# 616
# submitted to arxiv
# 617
# 618
# 619
# submitted to arxiv
# 620
# submitted to arxiv
# 621
# submitted to arxiv
# 622
# 623
# 624
# 625
# submitted to arxiv
# 626
# 627
# 628
# submitted to arxiv
# 629
# 630
# 631
# submitted to arxiv
# 632
# 633
# 634
# submitted to arxiv
# 635
# submitted to arxiv
# 636
# 637
# 638
# submitted to arxiv
# 639
# 640
# 641
# submitted to arxiv
# 642
# submitted to arxiv
# 643
# 644
# 645
# 646
# 647
# 648
# 649
# 650
# submitted to arxiv
# 651
# submitted to arxiv
# 652
# submitted to arxiv
# 653
# 654
# submitted to arxiv
# 655
# 656
# 657
# submitted to arxiv
# 658
# 659
# 660
# submitted to arxiv
# 661
# 662
# submitted to arxiv
# 663
# 664
# submitted to arxiv
# 665
# submitted to arxiv
# 666
# 667
# 668
# 669
# 670
# submitted to arxiv
# 671
# submitted to arxiv
# 672
# submitted to arxiv
# 673
# 674
# 675
# 676
# submitted to arxiv
# 677
# 678
# 679
# submitted to arxiv
# 680
# 681
# submitted to arxiv
# 682
# submitted to arxiv
# 683
# 684
# submitted to arxiv
# 685
# 686
# submitted to arxiv
# 687
# 688
# submitted to arxiv
# 689
# 690
# submitted to arxiv
# 691
# 692
# submitted to arxiv
# 693
# submitted to arxiv
# 694
# submitted to arxiv
# 695
# 696
# 697
# submitted to arxiv
# 698
# 699
# 700
# submitted to arxiv
# 701
# 702
# submitted to arxiv
# 703
# submitted to arxiv
# 704
# submitted to arxiv
# 705
# 706
# 707
# 708
# submitted to arxiv
# 709
# 710
# submitted to arxiv
# 711
# 712
# 713
# submitted to arxiv
# 714
# submitted to arxiv
# 715
# submitted to arxiv
# 716
# 717
# submitted to arxiv
# 718
# submitted to arxiv
# 719
# 720
# submitted to arxiv
# 721
# submitted to arxiv
# 722
# 723
# submitted to arxiv
# 724
# submitted to arxiv
# 725
# 726
# submitted to arxiv
# 727
# submitted to arxiv
# 728
# submitted to arxiv
# 729
# submitted to arxiv
# 730
# 731
# 732
# submitted to arxiv
# 733
# submitted to arxiv
# 734
# 735
# submitted to arxiv
# 736
# 737
# 738
# submitted to arxiv
# 739
# submitted to arxiv
# 740
# submitted to arxiv
# 741
# submitted to arxiv
# 742
# submitted to arxiv
# 743
# 744
# 745
# 746
# submitted to arxiv
# 747
# 748
# submitted to arxiv
# 749
# 750
# 751
# submitted to arxiv
# 752
# submitted to arxiv
# 753
# 754
# 755
# submitted to arxiv
# 756
# 757
# submitted to arxiv
# 758
# submitted to arxiv
# 759
# submitted to arxiv
# 760
# submitted to arxiv
# 761
# 762
# 763
# submitted to arxiv
# 764
# submitted to arxiv
# 765
# submitted to arxiv
# 766
# submitted to arxiv
# 767
# submitted to arxiv
# 768
# submitted to arxiv
# 769
# 770
# 771
# 772
# 773
# 774
# submitted to arxiv
# 775
# 776
# submitted to arxiv
# 777
# submitted to arxiv
# 778
# 779
# 780
# submitted to arxiv
# 781
# 782
# 783
# 784
# submitted to arxiv
# 785
# submitted to arxiv
# 786
# submitted to arxiv
# 787
# 788
# 789
# submitted to arxiv
# 790
# 791
# submitted to arxiv
# 792
# 793
# 794
# submitted to arxiv
# 795
# submitted to arxiv
# 796
# submitted to arxiv
# 797
# submitted to arxiv
# 798
# 799
# submitted to arxiv
# 800
# 801
# 802
# 803
# 804
# submitted to arxiv
# 805
# 806
# 807
# submitted to arxiv
# 808
# 809
# submitted to arxiv
# 810
# submitted to arxiv
# 811
# submitted to arxiv
# 812
# submitted to arxiv
# 813
# 814
# 815
# submitted to arxiv
# 816
# submitted to arxiv
# 817
# 818
# 819
# 820
# 821
# 822
# 823
# submitted to arxiv
# 824
# 825
# submitted to arxiv
# 826
# submitted to arxiv
# 827
# 828
# 829
# 830
# 831
# 832
# 833
# 834
# submitted to arxiv
# 835
# submitted to arxiv
# 836
# submitted to arxiv
# 837
# 838
# 839
# 840
# 841
# submitted to arxiv
# 842
# 843
# 844
# 845
# submitted to arxiv
# 846
# submitted to arxiv
# 847
# 848
# 849
# 850
# 851
# submitted to arxiv
# 852
# 853
# 854
# 855
# 856
# 857
# 858
# submitted to arxiv
# 859
# submitted to arxiv
# 860
# 861
# 862
# submitted to arxiv
# 863
# 864
# submitted to arxiv
# 865
# 866
# submitted to arxiv
# 867
# submitted to arxiv
# 868
# 869
# 870
# 871
# 872
# submitted to arxiv
# 873
# 874
# submitted to arxiv
# 875
# submitted to arxiv
# 876
# 877
# 878
# 879
# 880
# submitted to arxiv
# 881
# submitted to arxiv
# 882
# submitted to arxiv
# 883
# 884
# 885
# 886
# 887
# 888
# 889
# submitted to arxiv
# 890
# 891
# submitted to arxiv
# 892
# 893
# 894
# 895
# submitted to arxiv
# 896
# 897
# submitted to arxiv
# 898
# 899
# submitted to arxiv
# 900
# 901
# submitted to arxiv
# 902
# 903
# submitted to arxiv
# 904
# submitted to arxiv
# 905
# 906
# 907
# 908
# 909
# 910

# %%
open_review_data[open_review_data["submitted_arxiv"] == 1]
# Out:
#                                                  title               author_1  \
# 0    Certifying Some Distributional Robustness with...             Aman Sinha
# 2      Towards Neural Phrase-based Machine Translation           Po-Sen Huang
# 3    Weightless: Lossy Weight Encoding For Deep Neu...         Brandon Reagen
# 4    Interactive Grounded Language Acquisition and ...              Haonan Yu
# 5     A Boo(n) for Evaluating Architecture Performance          Ondrej Bajgar
# 6    Countering Adversarial Images using Input Tran...              Chuan Guo
# 7           A Neural Representation of Sketch Drawings               David Ha
# 8    The Kanerva Machine: A Generative Distributed ...                 Yan Wu
# 10   Multi-View Data Generation Without View Superv...           Mickael Chen
# 11   Towards Binary-Valued Gates for Robust LSTM Tr...             Zhuohan Li
# 12   On the importance of single directions for gen...          Ari S. Morcos
# 13                      Variational Continual Learning        Cuong V. Nguyen
# 14   Go for a Walk and Arrive at the Answer: Reason...           Rajarshi Das
# 15          Learning to Represent Programs with Graphs    Miltiadis Allamanis
# 16   Variational image compression with a scale hyp...         Johannes Ballé
# 17   Simulating Action Dynamics with Neural Process...       Antoine Bosselut
# 18   Evidence Aggregation for Answer Re-Ranking in ...          Shuohang Wang
# 19   QANet: Combining Local Convolution with Global...           Adams Wei Yu
# 20   Measuring the Intrinsic Dimension of Objective...            Chunyuan Li
# 22          Reinforcement Learning Algorithm Selection         Romain Laroche
# 23     Feature Incay for Representation Regularization             Yuhui Yuan
# 24                          Zero-Shot Visual Imitation          Deepak Pathak
# 25   Emergent Communication in a Multi-Modal, Multi...       Katrina Evtimova
# 29          Spatially Transformed Adversarial Examples           Chaowei Xiao
# 31   Characterizing Adversarial Subspaces Using Loc...             Xingjun Ma
# 32   Generating Adversarial Examples with Adversari...           Chaowei Xiao
# 34   Learning Sparse Latent Representations with th...  Aleksander Wieczorek*
# 35                               Demystifying MMD GANs      Mikołaj Bińkowski
# 36   Fix your classifier: the marginal value of tra...            Elad Hoffer
# 37   Flipout: Efficient Pseudo-Independent Weight P...             Yeming Wen
# ..                                                 ...                    ...
# 823  WHAI: Weibull Hybrid Autoencoding Inference fo...              Hao Zhang
# 825  Deep Learning for Physical Processes: Incorpor...    Emmanuel de Bezenac
# 826  DeepArchitect: Automatically Designing and Tra...        Renato Negrinho
# 834  Bounding and Counting Linear Regions of Deep N...           Thiago Serra
# 835  Jointly Learning to Construct and Control Agen...         Charles Schaff
# 836  Tandem Blocks in Deep Convolutional Neural Net...        Chris Hettinger
# 841  Learning Sparse Structured Ensembles with SG-M...            Yichi Zhang
# 845  Multimodal Sentiment Analysis To Explore the S...             Anthony Hu
# 846  Building Generalizable Agents with a Realistic...                  Yi Wu
# 851  Real-valued (Medical) Time Series Generation w...       Stephanie Hyland
# 858  Quadrature-based features for kernel approxima...       Marina Munkhoeva
# 859          Parametrizing filters of a CNN with a GAN         Yannic Kilcher
# 862      Visualizing the Loss Landscape of Neural Nets                 Hao Li
# 864  On Characterizing the Capacity of Neural Netwo...        William H. Guss
# 866         Variance Regularizing Adversarial Learning           Karan Grewal
# 867  The Information-Autoencoding Family: A Lagrang...          Shengjia Zhao
# 872  Revisiting The Master-Slave Architecture In Mu...           Xiangyu Kong
# 874     Connectivity Learning in Multi-Branch Networks            Karim Ahmed
# 875  AMPNet: Asynchronous Model-Parallel Training f...     Alexander L. Gaunt
# 880  Optimal transport maps for distribution preser...      Eirikur Agustsson
# 881  Neural Compositional Denotational Semantics fo...           Nitish Gupta
# 882                               Variational Bi-LSTMs       Samira Shabanian
# 889  Sequential Coordination of Deep Models for Lea...          Eric Crawford
# 891                                  Fraternal Dropout           Konrad Zolna
# 895  Prediction Under Uncertainty with Error Encodi...          Mikael Henaff
# 897  Learning To Generate Reviews and Discovering S...           Alec Radford
# 899  Covariant Compositional Networks For Learning ...            Risi Kondor
# 901  Automatic Goal Generation for Reinforcement Le...             David Held
# 903  Bayesian Uncertainty Estimation for Batch Norm...           Mattias Teye
# 904  Learning Efficient Tensor Representations with...             Qibin Zhao
#
#                      author_2             author_3  \
# 0           Hongseok Namkoong           John Duchi
# 2                  Chong Wang          Sitao Huang
# 3                  Udit Gupta         Robert Adolf
# 4               Haichao Zhang               Wei Xu
# 5               Rudolf Kadlec  and Jan Kleindienst
# 6                 Mayank Rana      Moustapha Cisse
# 7                 Douglas Eck
# 8                  Greg Wayne          Alex Graves
# 10            Ludovic Denoyer     Thierry Artières
# 11                      Di He             Fei Tian
# 12         David G.T. Barrett   Neil C. Rabinowitz
# 13                Yingzhen Li         Thang D. Bui
# 14        Shehzaad Dhuliawala        Manzil Zaheer
# 15          Marc Brockschmidt      Mahmoud Khademi
# 16               David Minnen        Saurabh Singh
# 17                  Omer Levy         Ari Holtzman
# 18                      Mo Yu           Jing Jiang
# 19                David Dohan     Minh-Thang Luong
# 20            Heerad Farkhoor          Rosanne Liu
# 22             Raphael Feraud
# 23               Kuiyuan Yang         Jianyuan Guo
# 24           Parsa Mahmoudieh         Guanghao Luo
# 25             Andrew Drozdov          Douwe Kiela
# 29                Jun-Yan Zhu                Bo Li
# 31                      Bo Li           Yisen Wang
# 32                      Bo Li          Jun-Yan Zhu
# 34              Mario Wieser*      Damian Murezzan
# 35       Dougal J. Sutherland        Michael Arbel
# 36                Itay Hubara        Daniel Soudry
# 37                 Paul Vicol             Jimmy Ba
# ..                        ...                  ...
# 823                   Bo Chen           Dandan Guo
# 825              Arthur Pajot    Patrick Gallinari
# 826              Geoff Gordon
# 834  Christian Tjandraatmadja  Srikumar Ramalingam
# 835               David Yunis     Ayan Chakrabarti
# 836        Tanner Christensen       Jeff Humpherys
# 841                Zhijian Ou
# 845              Seth Flaxman
# 846                  Yuxin Wu     Georgia Gkioxari
# 851         Cristóbal Esteban        Gunnar Rätsch
# 858           Yermek Kapushev       Evgeny Burnaev
# 859            Gary Becigneul       Thomas Hofmann
# 862                  Zheng Xu         Gavin Taylor
# 864      Ruslan Salakhutdinov
# 866             R Devon Hjelm        Yoshua Bengio
# 867              Jiaming Song        Stefano Ermon
# 872              Fangchen Liu               Bo Xin
# 874         Lorenzo Torresani
# 875        Matthew A. Johnson        Alan Lawrence
# 880            Alexander Sage         Radu Timofte
# 881                Mike Lewis
# 882             Devansh Arpit       Adam Trischler
# 889       Guillaume Rabusseau        Joelle Pineau
# 891             Devansh Arpit        Dendi Suhubdy
# 895                Junbo Zhao           Yann Lecun
# 897          Rafal Jozefowicz       Ilya Sutskever
# 899             Truong Son Hy           Horace Pan
# 901              Xinyang Geng      Carlos Florensa
# 903          Hossein Azizpour          Kevin Smith
# 904          Masashi Sugiyama         Longhao Yuan
#
#                               email_1                             email_2  \
# 0                  amans@stanford.edu                  hnamk@stanford.edu
# 2              huang.person@gmail.com                   chongw@google.com
# 3              reagen@fas.harvard.edu                ugupta@g.harvard.edu
# 4                  haonanyu@baidu.com              zhanghaichao@baidu.com
# 5                   ondrej@bajgar.org            rudolf_kadlec@cz.ibm.com
# 6                   cg563@cornell.edu                   mayankrana@fb.com
# 7                  hadavid@google.com                     deck@google.com
# 8                    yanwu@google.com                gregwayne@google.com
# 10               mickael.chen@lip6.fr             ludovic.denoyer@lip6.fr
# 11               lizhuohan@pku.edu.cn                    di_he@pku.edu.cn
# 12               arimorcos@google.com             barrettdavid@google.com
# 13                    vcn22@cam.ac.uk                     yl494@cam.ac.uk
# 14              rajarshi@cs.umass.edu            sdhuliawala@cs.umass.edu
# 15             miallama@microsoft.com              mabrocks@microsoft.com
# 16                  jballe@google.com                  dminnen@google.com
# 17         antoineb@cs.washington.edu          omerlevy@cs.washington.edu
# 18       shwang.2014@phdis.smu.edu.sg                      yum@us.ibm.com
# 19                   weiyu@cs.cmu.edu                   ddohan@google.com
# 20               chunyuan.li@duke.edu                     heerad@uber.com
# 22           romain.laroche@gmail.com           raphael.feraud@orange.com
# 23                yuyua@microsoft.com           kuiyuanyang@deepmotion.ai
# 24                pathak@berkeley.edu                parsa.m@berkeley.edu
# 25                     kve216@nyu.edu                      apd283@nyu.edu
# 29                   xiaocw@umich.edu               junyanzhu89@gmail.com
# 31    xingjunm@student.unimelb.edu.au            crystalboli@berkeley.edu
# 32                   xiaocw@umich.edu                   lxbosky@gmail.com
# 34     aleksander.wieczorek@unibas.ch              mario.wieser@unibas.ch
# 35             mikbinkowski@gmail.com                    dougal@gmail.com
# 36              elad.hoffer@gmail.com                itayhubara@gmail.com
# 37            wenyemin@cs.toronto.edu               pvicol@cs.toronto.edu
# ..                                ...                                 ...
# 823           zhanghao_xidian@163.com            bchen@mail.xidian.edu.cn
# 825       emmanuel.de_bezenac@lip6.fr                arthur.pajot@lip6.fr
# 826               negrinho@cs.cmu.edu                  ggordon@cs.cmu.edu
# 834                  tserra@gmail.com             ctjandra@andrew.cmu.edu
# 835                 cbschaff@ttic.edu                 dyunis@uchicago.edu
# 836          chrishettinger@gmail.com               tkchristensen@byu.edu
# 841  zhangyic17@mails.tsinghua.edu.cn                 ozj@tsinghua.edu.cn
# 845         anthony.hu@stats.ox.ac.uk            s.flaxman@imperial.ac.uk
# 846                  jxwuyi@gmail.com                 ppwwyyxxc@gmail.com
# 851      stephanie.hyland@inf.ethz.ch                      cr_est@ethz.ch
# 858  marina.munkhoeva@skolkovotech.ru                  kapushev@gmail.com
# 859        yannic.kilcher@inf.ethz.ch          gary.becigneul@inf.ethz.ch
# 862                  haoli@cs.umd.edu                     xuzh@cs.umd.edu
# 864                  wguss@cs.cmu.edu                 rsalakhu@cs.cmu.edu
# 866  karanraj.grewal@mail.utoronto.ca                  erroneus@gmail.com
# 867               sjzhao@stanford.edu               tsong@cs.stanford.edu
# 872               kxyzc1992@gmail.com              liufangchen@pku.edu.cn
# 874               karim.mmm@gmail.com                    lt@dartmouth.edu
# 875             algaunt@microsoft.com                matjoh@microsoft.com
# 880        aeirikur@vision.ee.ethz.ch               sagea@student.ethz.ch
# 881             nitishg@cis.upenn.edu              mikelewis@facebook.com
# 882             s.shabanian@gmail.com              devansharpit@gmail.com
# 889      eric.crawford@mail.mcgill.ca  guillaume.rabusseau@mail.mcgill.ca
# 891            konrad.zolna@gmail.com          devansh.arpit@umontreal.ca
# 895                    mbh305@nyu.edu                      j.zhao@nyu.edu
# 897                   alec@openai.com                    rafal@openai.com
# 899              risi@cs.uchicago.edu            hytruongson@uchicago.edu
# 901              dheld@andrew.cmu.edu             young.geng@berkeley.edu
# 903                       teye@kth.se                     azizpour@kth.se
# 904               qibin.zhao@riken.jp                sugi@k.u-tokyo.ac.jp
#
#                               email_3 accepted  submitted_arxiv
# 0                 jduchi@stanford.edu        a                1
# 2               shuang91@illinois.edu       ap                1
# 3            rdadolf@seas.harvard.edu       wp                1
# 4                    wei.xu@baidu.com       ap                1
# 5                   jankle@cz.ibm.com        r                1
# 6               moustaphacisse@fb.com       ap                1
# 7                                           ap                1
# 8                  gravesa@google.com       ap                1
# 10   thierry.artieres@lif.univ-mrs.fr       ap                1
# 11                fetia@microsoft.com        r                1
# 12                     ncr@google.com       ap                1
# 13                    tdb40@cam.ac.uk       ap                1
# 14                     manzil@cmu.edu       ap                1
# 15                    mkhademi@sfu.ca        a                1
# 16            saurabhsingh@google.com       ap                1
# 17             ahai@cs.washington.edu       ap                1
# 18               jingjiang@smu.edu.sg       ap                1
# 19              thangluong@google.com       ap                1
# 20                   rosanne@uber.com       ap                1
# 22                                          ap                1
# 23              1701214082@pku.edu.cn       wp                1
# 24            michaelluo@berkeley.edu        a                1
# 25                      dkiela@fb.com       ap                1
# 29                  lxbosky@gmail.com       ap                1
# 31     wangys14@mails.tsinghua.edu.cn        a                1
# 32               junyanz@berkeley.edu        r                1
# 34               d.murezzan@unibas.ch       ap                1
# 35          michael.n.arbel@gmail.com       ap                1
# 36            daniel.soudry@gmail.com       ap                1
# 37              jimmy@psi.toronto.edu       ap                1
# ..                                ...      ...              ...
# 823                gdd_xidian@126.com       ap                1
# 825         patrick.gallinari@lip6.fr       ap                1
# 826                                          r                1
# 834     srikumar.ramalingam@gmail.com        r                1
# 835                    ayan@wustl.edu       wp                1
# 836                jeffh@math.byu.edu        r                1
# 841                                          r                1
# 845                                          r                1
# 846        georgia.gkioxari@gmail.com       wp                1
# 851               raetsch@inf.ethz.ch        r                1
# 858             e.burnaev@skoltech.ru        r                1
# 859        thomas.hofmann@inf.ethz.ch        r                1
# 862                   taylor@usna.edu       wp                1
# 864                                          r                1
# 866        yoshua.umontreal@gmail.com        r                1
# 867             ermon@cs.stanford.edu        r                1
# 872               boxin@microsoft.com        r                1
# 874                                          r                1
# 875              allawr@microsoft.com        r                1
# 880    radu.timofte@vision.ee.ethz.ch        r                1
# 881                                          r                1
# 882      adam.trischler@microsoft.com        r                1
# 889              jpineau@cs.mcgill.ca        r                1
# 891                 dasuhubd@ncsu.edu       ap                1
# 895                   yann@cs.nyu.edu        r                1
# 897                   ilya@openai.com        r                1
# 899             hopan@cs.uchicago.edu       wp                1
# 901             florensa@berkeley.edu        r                1
# 903                     ksmith@kth.se        r                1
# 904             longhao.yuan@riken.jp       wp                1
#
# [492 rows x 9 columns]

# %%
open_review_data.to_csv("open_review_arxiv_data.csv", index = False)
